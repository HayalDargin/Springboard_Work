# %% [markdown]
# Importing the libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Loading the Data

# %%
self_harm = '/Users/hayaldargin/Desktop/Springboard/Springboard_Work/Capstone_2/Data/Self_harm_All_Injury_Causes.csv'
#Read the csv file into data frame 
Self_harm = pd.read_csv(self_harm)
#Observe the first 5 entries
Self_harm.head(5)
# Out:
#   Sex Race/Ethnicity  First Year  Last Year              Cause of Injury  \
# 0   B              A        2001       2018  Self-harm All Injury Causes
# 1   B              W        2001       2018  Self-harm All Injury Causes
# 2   B              B        2001       2018  Self-harm All Injury Causes
# 3   B              H        2001       2018  Self-harm All Injury Causes
# 4   B              O        2001       2018  Self-harm All Injury Causes
#
#         Disp  ageRangLo  ageRangHi Age Group  Year  ...  Population records  \
# 0  All Cases          0        199     00-04  2001  ...  19,298,217       .
# 1  All Cases          0        199     00-04  2001  ...  11,435,173       .
# 2  All Cases          0        199     00-04  2001  ...   3,120,018       .
# 3  All Cases          0        199     00-04  2001  ...   3,718,198       .
# 4  All Cases          0        199     00-04  2001  ...   1,024,828       .
#
#   suppressed cv Number of$Cases (Sample) Standard$Error CV  \
# ...

# %%
social_media = '/Users/hayaldargin/Desktop/Springboard/Springboard_Work/Capstone_2/Data/users-by-social-media-platform.csv'
#Read the csv file into data frame 
Social_media = pd.read_csv(social_media)
#Observe the first 5 entries
Social_media.head(5)
# Out:
#      Entity  Year  Monthly active users (Statista and TNW (2019))
# 0  Facebook  2008                                       100000000
# 1  Facebook  2009                                       276000000
# 2  Facebook  2010                                       517750000
# 3  Facebook  2011                                       766000000
# 4  Facebook  2012                                       979750000

# %% [markdown]
# ###  Pick the columns
#
#
# 1. Self_harm:
#     * `Sex`
#     * `Race/Ethnicity`
#     * `Cause of Injury`
#     * `Disp`
#     * `Age Group`
#     * `Year`
#     * `Population`
# 2. Social_media:
#     * `Entity`#Platform
#     * `Year`
#     * `Monthly active users (Statista and TNW (2019))`

# %% [markdown]
# Subsetting the data frame

# %%
#Subset DataFrame object Self_harm by the columns
Self_harm = Self_harm[['Sex','Race/Ethnicity', 'Cause of Injury','Disp','Age Group','Year','Population']]

#Check the first five entries
Self_harm.head(5)
# Out:
#   Sex Race/Ethnicity              Cause of Injury       Disp Age Group  Year  \
# 0   B              A  Self-harm All Injury Causes  All Cases     00-04  2001
# 1   B              W  Self-harm All Injury Causes  All Cases     00-04  2001
# 2   B              B  Self-harm All Injury Causes  All Cases     00-04  2001
# 3   B              H  Self-harm All Injury Causes  All Cases     00-04  2001
# 4   B              O  Self-harm All Injury Causes  All Cases     00-04  2001
#
#    Population
# 0  19,298,217
# 1  11,435,173
# 2   3,120,018
# 3   3,718,198
# 4   1,024,828

# %%
#Subset DataFrame object Social_media by the columns
Social_media = Social_media[['Entity','Year','Monthly active users (Statista and TNW (2019))']]

#Check the first five entries
Social_media.head(5)
# Out:
#      Entity  Year  Monthly active users (Statista and TNW (2019))
# 0  Facebook  2008                                       100000000
# 1  Facebook  2009                                       276000000
# 2  Facebook  2010                                       517750000
# 3  Facebook  2011                                       766000000
# 4  Facebook  2012                                       979750000
